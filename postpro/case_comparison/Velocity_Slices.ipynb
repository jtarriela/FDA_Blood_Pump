# %%
from postpro.ASCII_time_avg import ascii_averaging
import pandas as pd
import numpy as np
import glob
import os
import math
import psutil
from plotly import tools



# pd.options.plotting.backend = "plotly"
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from pint import UnitRegistry

ureg = UnitRegistry()
Q_ = ureg.Quantity

# %%
C1_Experimental = {
    'D1': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C1_sampling_coordinates/C1_Experimental_Slice_Data/C1_D1.csv',
    'D2': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C1_sampling_coordinates/C1_Experimental_Slice_Data/C1_D2.csv',
    'D3': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C1_sampling_coordinates/C1_Experimental_Slice_Data/C1_D3.csv',
    'D4': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C1_sampling_coordinates/C1_Experimental_Slice_Data/C1_D4.csv',
    'Q1': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C1_sampling_coordinates/C1_Experimental_Slice_Data/C1_Q1.csv',
    'Q2': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C1_sampling_coordinates/C1_Experimental_Slice_Data/C1_Q2.csv'}

C4_Experimental = {
    'Q1': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C4_sampling_coordinates/C4_Experimental_Slice_Data/C4_Q1.csv',
    'Q2': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C4_sampling_coordinates/C4_Experimental_Slice_Data/C4_Q2.csv'}

C5_Experimental = {
    'D1': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C5_sampling_coordinates/C5_Experimental_Slice_Data/C5_D1.csv',
    'D2': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C5_sampling_coordinates/C5_Experimental_Slice_Data/C5_D2.csv',
    'D3': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C5_sampling_coordinates/C5_Experimental_Slice_Data/C5_D3.csv',
    'D4': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C5_sampling_coordinates/C5_Experimental_Slice_Data/C5_D4.csv',
    'Q1': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C5_sampling_coordinates/C5_Experimental_Slice_Data/C5_Q1.csv',
    'Q2': r'/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/postpro/C5_sampling_coordinates/C5_Experimental_Slice_Data/C5_Q2.csv'}


for i in enumerate(C1_Experimental):
    C1_Experimental[i[1]] = pd.read_csv(C1_Experimental[i[1]])
for i in enumerate(C4_Experimental):
    C4_Experimental[i[1]] = pd.read_csv(C4_Experimental[i[1]])
for i in enumerate(C5_Experimental):
    C5_Experimental[i[1]] = pd.read_csv(C5_Experimental[i[1]])

# %%
C1_IDDES_diff_ascii = {
    'D1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-IDDES_19M_BP/Velocity_slices/D1/*",
    'D2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-IDDES_19M_BP/Velocity_slices/D2/*",
    'D3': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-IDDES_19M_BP/Velocity_slices/D3/*",
    'D4': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-IDDES_19M_BP/Velocity_slices/D4/*"}
C1_IDDES_quad_ascii = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-IDDES_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-IDDES_19M_BP/Velocity_slices/Q2/*"}
C1_SBES_diff_ascii = {
    'D1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-SBES_19M_BP/Velocity_slices/D1/*",
    'D2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-SBES_19M_BP/Velocity_slices/D2/*",
    'D3': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-SBES_19M_BP/Velocity_slices/D3/*",
    'D4': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-SBES_19M_BP/Velocity_slices/D4/*"}
C1_SBES_quad_ascii = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-SBES_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-SBES_19M_BP/Velocity_slices/Q2/*"}
C1_KW_diff_ascii = {
    'D1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-KW_19M_BP/Velocity_slices/D1/*",
    'D2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-KW_19M_BP/Velocity_slices/D2/*",
    'D3': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-KW_19M_BP/Velocity_slices/D3/*",
    'D4': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-KW_19M_BP/Velocity_slices/D4/*"}
C1_KW_quad_ascii = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-KW_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_1-KW_19M_BP/Velocity_slices/Q2/*"}
C4_SBES_quad_diff = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_4-SBES_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_4-SBES_19M_BP/Velocity_slices/Q2/*"}
C4_IDDES_quad_diff = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_4-IDDES_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_4-IDDES_19M_BP/Velocity_slices/Q2/*"}
C4_KW_quad_diff = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_4-KW_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_4-KW_19M_BP/Velocity_slices/Q2/*"}
C5_SBES_diff_ascii = {
    'D1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-SBES_19M_BP/Velocity_slices/D1/*",
    'D2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-SBES_19M_BP/Velocity_slices/D2/*",
    'D3': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-SBES_19M_BP/Velocity_slices/D3/*",
    'D4': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-SBES_19M_BP/Velocity_slices/D4/*"}
C5_SBES_quad_ascii = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-SBES_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-SBES_19M_BP/Velocity_slices/Q2/*"}
C5_IDDES_diff_ascii = {
    'D1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-IDDES_19M_BP/Velocity_slices/D1/*",
    'D2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-IDDES_19M_BP/Velocity_slices/D2/*",
    'D3': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-IDDES_19M_BP/Velocity_slices/D3/*",
    'D4': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-IDDES_19M_BP/Velocity_slices/D4/*"}
C5_IDDES_quad_ascii = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-IDDES_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-IDDES_19M_BP/Velocity_slices/Q2/*"}
C5_KW_diff_ascii = {
    'D1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-KW_19M_BP/Velocity_slices/D1/*",
    'D2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-KW_19M_BP/Velocity_slices/D2/*",
    'D3': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-KW_19M_BP/Velocity_slices/D3/*",
    'D4': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-KW_19M_BP/Velocity_slices/D4/*"}
C5_KW_quad_ascii = {
    'Q1': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-KW_19M_BP/Velocity_slices/Q1/*",
    'Q2': r"/Users/jdtarriela/Documents/GitHub/FDA_Blood_Pump/Core/Cond_5-KW_19M_BP/Velocity_slices/Q2/*"}


diff_ascii = {'C1_IDDES':C1_IDDES_diff_ascii,
              'C1_SBES':C1_SBES_diff_ascii,
              'C1_KW':C1_KW_diff_ascii,
              'C5_SBES':C5_SBES_diff_ascii,
              'C5_IDDES':C5_IDDES_diff_ascii,
              'C5_KW':C5_KW_diff_ascii}

quad_ascii ={'C1_IDDES':C1_IDDES_quad_ascii,
             'C1_SBES':C1_SBES_quad_ascii,
             'C1_KW':C1_KW_quad_ascii,
             'C4_SBES':C4_SBES_quad_diff,
             'C4_IDDES':C4_IDDES_quad_diff,
             'C4_KW':C4_KW_quad_diff,
             'C5_IDDES':C5_IDDES_quad_ascii,
             'C5_SBES':C5_SBES_quad_ascii,
             'C5_KW':C5_KW_quad_ascii}

del C1_IDDES_diff_ascii,C1_SBES_diff_ascii,C1_KW_diff_ascii, C5_SBES_diff_ascii,C5_IDDES_diff_ascii,C1_IDDES_quad_ascii, C1_SBES_quad_ascii,C4_SBES_quad_diff,C4_IDDES_quad_diff,C5_IDDES_quad_ascii,C5_SBES_quad_ascii,C5_KW_quad_ascii


for case in diff_ascii:
    diff_slice = ['D1','D2','D3','D4']
    # print(case)
    for d_slice in diff_slice:
        # print(d_slice)
        # print(diff_ascii[case][d_slice])
        file_paths = glob.glob(diff_ascii[case][d_slice])
        # print(file_paths)
        diff_avg_obj = ascii_averaging(file_paths)
        #overwrite path in dict with df paired to correct key
        diff_ascii[case][d_slice] = diff_avg_obj.diffuser_ave()
del diff_slice, case, d_slice
# #
for case in quad_ascii:
    quad_slice = ['Q1','Q2']
    for q_slice in quad_slice:
        file_paths = glob.glob(quad_ascii[case][q_slice])
        diff_avg_obj = ascii_averaging(file_paths)
        #overwrite path in dict with df paired to correct key
        quad_ascii[case][q_slice] = diff_avg_obj.blade_quadrant_ave()
del quad_slice, case, q_slice

# %%
color10_16 = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF',
              '#FECB52']

fig = go.Figure()
sbes_x = [1.2, 4.2, 5.2]
sbes_y = [195.0517289, 91.26441309, 300.0389234]
iddes_x = [1.3, 4.3, 5.3]
iddes_y = [197.600018, 94.50900554, 312.4812035]
kw_x = [1.1, 4.1, 5.1]
kw_y = [188.1331821, 64.74052803, 284.3971587]
experimental_x = [1, 4, 5]
experimental_y = [173.91, 38.04, 273.913]

fig.add_trace(go.Scatter(x=experimental_x,
                         y=experimental_y,
                         mode='markers',
                         name = 'Experimental',
                         error_y=dict(
                             type='data',
                             symmetric=False,
                             array=[8.09, 9.78, 10.867],
                             arrayminus=[7.61, 7.6053, 9.783]),
                         marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),

                         ))

fig.add_trace(go.Scatter(x=sbes_x,
                         y=sbes_y,
                         mode='markers',
                         name='SBES',
                         marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'triangle-right'),
                         ))

fig.add_trace(go.Scatter(x=iddes_x,
                         y=iddes_y,
                         mode = 'markers',
                         name='IDDES',
                         marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'x'),
                         ))

fig.add_trace(go.Scatter(x=kw_x,
                         y=kw_y,
                         mode='markers',
                         name='KW-SST',
                         marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'diamond'),
                         ))



fig.update_layout(
    title="Case Comparison: Average Pressure Head Rise",
    xaxis_title="Case Condition",
    yaxis_title="Pressure (mmHg)",
    legend_title=None,height=500, width=600,)
fig.show()
fig.write_image("/Users/jdtarriela/Downloads/phead.png")
# Out:
# <div>                            <div id="74aabf57-036f-4978-9ff0-4f2d38a1e7cc" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74aabf57-036f-4978-9ff0-4f2d38a1e7cc")) {                    Plotly.newPlot(                        "74aabf57-036f-4978-9ff0-4f2d38a1e7cc",                        [{"error_y": {"array": [8.09, 9.78, 10.867], "arrayminus": [7.61, 7.6053, 9.783], "symmetric": false, "type": "data"}, "marker": {"color": "black", "line": {"color": "black"}, "size": 7, "symbol": "circle"}, "mode": "markers", "name": "Experimental", "type": "scatter", "x": [1, 4, 5], "y": [173.91, 38.04, 273.913]}, {"marker": {"color": "red", "line": {"color": "black"}, "size": 7, "symbol": "triangle-right"}, "mode": "markers", "name": "SBES", "type": "scatter", "x": [1.2, 4.2, 5.2], "y": [195.0517289, 91.26441309, 300.0389234]}, {"marker": {"color": "blue", "line": {"color": "black"}, "size": 7, "symbol": "x"}, "mode": "markers", "name": "IDDES", "type": "scatter", "x": [1.3, 4.3, 5.3], "y": [197.600018, 94.50900554, 312.4812035]}, {"marker": {"color": "green", "line": {"color": "black"}, "size": 7, "symbol": "diamond"}, "mode": "markers", "name": "KW-SST", "type": "scatter", "x": [1.1, 4.1, 5.1], "y": [188.1331821, 64.74052803, 284.3971587]}],                        {"height": 500, "legend": {"title": {}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "his ...

# %%
color10_16 = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF',
              '#FECB52']
fig1 = make_subplots(
    rows=4,
    cols=1,
    shared_xaxes=True,
    x_title="Velocity Magnitude (m/s)",
    y_title="Y-Coordinate from Origin",
    subplot_titles=("X = 0.020m", "X = 0.025m", "X = 0.030m", "X = 0.035m"))


fig1.add_trace(go.Scatter(x=diff_ascii["C1_SBES"]['D1']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_SBES"]["D1"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              symbol = 'triangle-right')
                          ),
               row=1, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_IDDES"]['D1']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_IDDES"]["D1"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              symbol = 'x')
                          ),
               row=1, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_KW"]['D1']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_KW"]["D1"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle')
                          ),
               row=1, col=1)
fig1.add_trace(go.Scatter(x=C1_Experimental["D1"]['Velocity_Magnitude'],
                          y=C1_Experimental["D1"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle')
                          ),
               row=1, col=1)





fig1.add_trace(go.Scatter(x=diff_ascii["C1_SBES"]['D2']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_SBES"]["D2"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
               row=2, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_IDDES"]['D2']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_IDDES"]["D2"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
               row=2, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_KW"]['D2']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_KW"]["D2"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=2, col=1)
fig1.add_trace(go.Scatter(x=C1_Experimental["D2"]['Velocity_Magnitude'],
                          y=C1_Experimental["D2"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=2, col=1)



fig1.add_trace(go.Scatter(x=diff_ascii["C1_SBES"]['D3']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_SBES"]["D3"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
               row=3, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_IDDES"]['D3']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_IDDES"]["D3"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
               row=3, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_KW"]['D3']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_KW"]["D3"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=3, col=1)
fig1.add_trace(go.Scatter(x=C1_Experimental["D3"]['Velocity_Magnitude'],
                          y=C1_Experimental["D3"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=3, col=1)




fig1.add_trace(go.Scatter(x=diff_ascii["C1_SBES"]['D4']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_SBES"]["D4"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
               row=4, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_IDDES"]['D4']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_IDDES"]["D4"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
               row=4, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C1_KW"]['D4']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C1_KW"]["D4"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=4, col=1)

fig1.add_trace(go.Scatter(x=C1_Experimental["D4"]['Velocity_Magnitude'],
                          y=C1_Experimental["D4"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=4, col=1)



fig1.update_layout(height=1000, width=700,
                   title_text="Condition 1: Diffuser Velocity Magnitude",
                   xaxis=dict(
                       tickmode='linear',
                       tick0=0,
                       dtick=0.75
                   ))
fig.update_layout(legend= {'itemsizing': 'constant'})

fig1.show()
fig1.write_image("/Users/jdtarriela/Downloads/C1-diff.png")
# Out:
# <div>                            <div id="2486bf8e-d236-4acc-8e43-dc305173a22e" class="plotly-graph-div" style="height:1000px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2486bf8e-d236-4acc-8e43-dc305173a22e")) {                    Plotly.newPlot(                        "2486bf8e-d236-4acc-8e43-dc305173a22e",                        [{"marker": {"color": "red", "size": 7, "symbol": "triangle-right"}, "mode": "markers", "name": "SBES-ASCII", "type": "scatter", "x": [1.1591493750292683, 1.3558684538463415, 1.6801839845365854, 2.0882441599195123, 2.6862757684878047, 3.0699868981463414, 3.27184622802439, 3.5403779601463414, 3.6757726362682925, 3.6830309802439025, 3.6297408776829267, 3.6025549701219512, 3.617858512902439, 3.613999706804878, 3.594726297780488, 3.5619389679512197, 3.5364993470487804, 3.513207523414634, 3.493387399195122, 3.482610022878049, 3.451979393878049, 3.397526773658537, 3.3437935800000003, 3.3132508064634147, 3.281568829414634, 3.2695003718536584, 3.273127003731707, 3.2607076217317075, 3.262809671317073, 3.2528289686341463, 3.2682303123658536, 3.1187839905365853], "xaxis": "x", "y": [-0.02984774485, -0.02980891429, -0.02971169166, -0.029591044410000003, -0.029469043019999995, -0.029325041965365853, -0.02918104269, -0.02903704345, -0.02889304236, -0.028749043119999998, -0.028605042075365857, -0.02846104279, -0.028317043559999998, -0.028173042505365856, -0.02802904323, -0.027885042175365853, -0.027741042899999995, -0.02759704366, -0.02745304257, -0.02730904333, -0.027165042285365853, -0.027021042999999998, -0.02687704377, -0.02673304267, -0.026589043439999998, -0.026445042385365856, -0.02630104311, -0.026157043869999997, -0.02607314475, -0.026027008889999998, -0.02592459694, -0.02583321184], "yaxis": "y"}, {"marker": {"color": "green", "size": 7, "symbol": "x"}, "mode": "markers", "name": "IDDES-ASCII", "type": "scatter", "x": [1.6213436836560975, 1.8336381759268294, 2.082486682609756, 2.333698135536585, 2.5971567852439024, 2.888108969317073, 3.1932699864146343, 3.4060334470975606, 3.5350031078292683, 3.600506974682927, 3.6185470860487805, 3.602547967951219, 3.5787633965121954, 3.557913050463415, 3.5409880522682924, 3.5329787913658532, 3.5299311890487806, 3.5300827902682927, 3.524158956682927, 3.4972211561707316, 3.4469013746097557, 3.392777632926829, 3.355967571634146, 3.3089866445853655, 3.2411287777317073, 3.183656872317073, 3.1416557856341467, 3.1284360983902437, 3.1348343617317074, 3.09720289497561, 3.0979707995121952, 2.9095581376585367], "xaxis": "x", "y": [-0.02984774485, -0.02980891429, -0.02971169166, -0.029591044410000003, -0.029469043019999995, -0.02932504378, -0.02918104269, -0.02903704345, -0.02889304422, -0.028749043119999998, -0.02860504389, -0.02846104279, -0.028317043559999998, -0.02817304432, -0.02802904323, -0.027885043990000004, -0.027741042899999995, -0.02759704366, -0.02745304257, -0.02730904333, -0.0271650441, -0.027021042999999998, -0.02687704377, -0.02673304267, -0.026589043439999998, -0.026445042385365856, -0.02630104311, -0.026157043869999997, -0.02607314475, -0.026027008889999998, -0.02592459694, -0.02583321184], "yaxis": "y"}, {"marker": {"color": "blue", "line": {"color": "blue"}, "size": 7, "symbol": "circle"}, "mode": "markers", "name": "KW-SST-ASCII", "type": "scatter", "x": [3.3053546337999995, 3.4772600052000002, 3.50270349635, 3.51307532835, 3.51970612365, 3.5270566521999998, 3.5351911084000003, 3.5445866875, 3.5553357384999997, 3.5678492062000005, 3.5823033520000003, 3.59891050795, 3.6177305682000003, 3.6386256451500003, 3.66094668295, 3.6835117642, 3.7044066911499995, 3.7210093424, 3.72998095815, 3.7272101748499997, 3.70733675765, 3.66260646775, 3.58084407895, 3.44385766265, 3.22667847685, 2.9065222404, 2.4894483927, 2.0327761229, 1.63921802097, 1.323722820175, 1.12006822255, 3.44 ...

# %%
color10_16 = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF',
              '#FECB52']
fig1 = make_subplots(
    rows=4,
    cols=1,
    shared_xaxes=True,
    x_title="Velocity Magnitude (m/s)",
    y_title="Y-Coordinate from Origin",
    subplot_titles=("X = 0.020m", "X = 0.025m", "X = 0.030m", "X = 0.035m"))


fig1.add_trace(go.Scatter(x=diff_ascii["C5_SBES"]['D1']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_SBES"]["D1"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right')
                          ),
               row=1, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_IDDES"]['D1']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_IDDES"]["D1"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x')
                          ),
               row=1, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_KW"]['D1']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_KW"]["D1"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle')
                          ),
               row=1, col=1)
fig1.add_trace(go.Scatter(x=C5_Experimental["D1"]['Velocity_Magnitude'],
                          y=C5_Experimental["D1"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle')
                          ),
               row=1, col=1)



fig1.add_trace(go.Scatter(x=diff_ascii["C5_SBES"]['D2']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_SBES"]["D2"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
               row=2, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_IDDES"]['D2']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_IDDES"]["D2"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
               row=2, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_KW"]['D2']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_KW"]["D2"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=2, col=1)
fig1.add_trace(go.Scatter(x=C5_Experimental["D2"]['Velocity_Magnitude'],
                          y=C5_Experimental["D2"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=2, col=1)




fig1.add_trace(go.Scatter(x=diff_ascii["C5_SBES"]['D3']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_SBES"]["D3"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
               row=3, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_IDDES"]['D3']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_IDDES"]["D3"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
               row=3, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_KW"]['D3']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_KW"]["D3"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=3, col=1)
fig1.add_trace(go.Scatter(x=C5_Experimental["D3"]['Velocity_Magnitude'],
                          y=C5_Experimental["D3"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          line=dict(color='black'),
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=3, col=1)




fig1.add_trace(go.Scatter(x=diff_ascii["C5_SBES"]['D4']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_SBES"]["D4"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),

               row=4, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_IDDES"]['D4']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_IDDES"]["D4"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
               row=4, col=1)

fig1.add_trace(go.Scatter(x=diff_ascii["C5_KW"]['D4']['velocity-magnitude_bin_mean'],
                          y=diff_ascii["C5_KW"]["D4"]['y-coordinate_bin_mean'],
                          mode='markers',
                          name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
               row=4, col=1)
fig1.add_trace(go.Scatter(x=C5_Experimental["D4"]['Velocity_Magnitude'],
                          y=C5_Experimental["D4"]['y-coord'],
                          mode='markers+lines',
                          name='Experimental',
                          marker=dict(
                              color='black',
                              size = 7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False),
               row=4, col=1)



fig1.update_layout(height=1000, width=700,
                   title_text="Condition 5: Diffuser Velocity Magnitude",
                   xaxis=dict(
                       tickmode='linear',
                       tick0=0,
                       dtick=0.75),
                   )

fig.update_layout(legend= {'itemsizing': 'constant'})


fig1.show()
fig1.write_image("/Users/jdtarriela/Downloads/C5-diff.png")
# Out:
# <div>                            <div id="e95ed93c-e550-4512-9a14-aeab08c55b0e" class="plotly-graph-div" style="height:1000px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e95ed93c-e550-4512-9a14-aeab08c55b0e")) {                    Plotly.newPlot(                        "e95ed93c-e550-4512-9a14-aeab08c55b0e",                        [{"marker": {"color": "red", "line": {"color": "red"}, "size": 7, "symbol": "triangle-right"}, "mode": "markers", "name": "SBES-ASCII", "type": "scatter", "x": [5.022676667268293, 5.599494638658537, 6.386797659268293, 6.990187590804878, 7.414009725121952, 7.508357023853659, 7.509945454682927, 7.493953960390244, 7.406854305390244, 7.3307213180243895, 7.2781026062195116, 7.2344077794390245, 7.198662185658537, 7.192827554121952, 7.163062741609756, 7.135153414243902, 7.112698330170732, 7.055875022804877, 6.985381251756097, 6.949717427414634, 6.925518025512195, 6.928058675292683, 6.926784627536585, 6.934961126170732, 6.94587213204878, 6.959015448121951, 6.884800713682926, 6.6786694992439015, 6.254975787512196, 6.582129368317073, 6.28739734897561, 6.050686653463415], "xaxis": "x", "y": [-0.02984774512219512, -0.02980891429, -0.029711691614634148, -0.029591044364634143, -0.029469043019999995, -0.029325043235609756, -0.02918104269, -0.02903704345, -0.028893042949756097, -0.028749043119999998, -0.02860504289195122, -0.02846104279, -0.028317043559999998, -0.028173043276585364, -0.02802904323, -0.027885043037317075, -0.027741042899999995, -0.02759704366, -0.027453042706097563, -0.02730904333, -0.02716504301121951, -0.027021042999999998, -0.02687704377, -0.02673304267, -0.026589043439999998, -0.026445043065853657, -0.02630104311, -0.026157043688536583, -0.02607314475, -0.026027008889999998, -0.02592459694, -0.02583321184], "yaxis": "y"}, {"marker": {"color": "green", "line": {"color": "green"}, "size": 7, "symbol": "x"}, "mode": "markers", "name": "IDDES-ASCII", "type": "scatter", "x": [4.725920594634147, 5.6436969586341466, 6.658966216609755, 7.149629987634146, 7.444272228365853, 7.536463609219512, 7.525872247317073, 7.443198309292684, 7.3473591597804875, 7.311311700536585, 7.272144432170732, 7.190934976341463, 7.109537178048781, 7.051982154195121, 7.036730920634146, 7.034821233292684, 7.0050974832195125, 6.985555714634146, 6.988192518707318, 6.991660935292684, 7.001160963902439, 7.029231936878049, 7.056753587853658, 7.067684660512196, 7.074723658756098, 7.071363034756097, 6.989907611512196, 6.709336068341464, 6.372880616658536, 6.479446226414634, 6.2616008680975614, 5.866867911268293], "xaxis": "x", "y": [-0.029847744895365857, -0.02980891429, -0.02971169166, -0.029591044410000003, -0.029469043019999995, -0.029325041965365853, -0.02918104269, -0.02903704345, -0.02889304236, -0.028749043119999998, -0.028605042029999996, -0.02846104279, -0.028317043559999998, -0.028173042459999995, -0.02802904323, -0.02788504213, -0.027741042899999995, -0.02759704366, -0.02745304257, -0.02730904333, -0.027165042285365853, -0.027021042999999998, -0.02687704377, -0.02673304267, -0.026589043439999998, -0.0264450442, -0.02630104311, -0.026157043869999997, -0.02607314475, -0.026027008889999998, -0.02592459694, -0.02583321184], "yaxis": "y"}, {"marker": {"color": "blue", "line": {"color": "blue"}, "size": 7, "symbol": "circle"}, "mode": "markers", "name": "KW-SST-ASCII", "type": "scatter", "x": [5.67054038655, 6.3191661132, 6.2538610195499995, 6.55186953085, 6.7627473541, 6.8704486351, 6.89388933025, 6.89249965315, 6.894114584, 6.904954833300001, 6.92441561145, 6.951047794999999, 6.984027697, 7.022950826000001, 7.06770772525, 7.118107565450001, 7.173503558049999, 7.2325250058999995, 7.2930259777, 7.352309291349999, 7.407315292, 7.45477676495, 7.49100683285, 7.5109470888, 7.50559160835, 7.457467755400001, 7.32990660315, 7.0463791036000005,  ...

# %%
color10_16 = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF',
              '#FECB52']
fig = make_subplots(
    rows=1,
    cols=2,
    shared_yaxes=True,
    x_title="Radius (m)",
    y_title="Velocity Magnitude (m/s)",
    subplot_titles=("Quadrant 1", "Quadrant 2"))


fig.add_trace(go.Scatter(x=quad_ascii["C1_SBES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C1_SBES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 4.5,
                              line=dict(color='red'),
                              symbol = 'triangle-right')
                          ),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C1_IDDES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C1_IDDES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 4.5,
                              line=dict(color='green'),
                              symbol = 'x')
                          ),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C1_KW"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C1_KW"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 4.5,
                              line=dict(color='blue'),
                              opacity = 0.7,
                              symbol = 'circle')
                          ),
              row=1, col=1)


fig.add_trace(go.Scatter(x=C1_Experimental["Q1"]['radius'],
                         y=C1_Experimental["Q1"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                          marker=dict(
                              color='black',
                              size = 4.5,
                              line=dict(color='black'),
                              symbol = 'circle')
                          ),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C1_SBES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C1_SBES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size = 4.5,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C1_IDDES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C1_IDDES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size = 4.5,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C1_KW"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C1_KW"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size = 4.5,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
              row=1, col=2)



fig.add_trace(go.Scatter(x=C1_Experimental["Q2"]['radius'],
                         y=C1_Experimental["Q2"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                          marker=dict(
                              color='black',
                              size = 4.5,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False),

              row=1, col=2)

fig.update_layout(height=400, width=1200,
                  title_text="Condition 1: Velocity Magnitude vs Experimental")

fig.show()
fig.write_image("/Users/jdtarriela/Downloads/C1-velomag.png")
# Out:
# <div>                            <div id="5e4e60ad-679c-4379-be77-8ad39f26e11a" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e4e60ad-679c-4379-be77-8ad39f26e11a")) {                    Plotly.newPlot(                        "5e4e60ad-679c-4379-be77-8ad39f26e11a",                        [{"marker": {"color": "red", "line": {"color": "red"}, "size": 4.5, "symbol": "triangle-right"}, "mode": "markers", "name": "SBES-ASCII", "type": "scatter", "x": [0.029992993419483107, 0.029980615409212416, 0.029970134021963427, 0.029957561083566373, 0.029942472577957305, 0.02992437564964015, 0.0299026595453081, 0.029876612800332616, 0.02984537145095264, 0.02981023941621481, 0.02972614855245556, 0.02960912519445417, 0.02953715153877151, 0.02943554602187993, 0.029333721881713737, 0.029231897727405424, 0.029130073637254103, 0.029028252049226006, 0.02892642789491768, 0.028824603754751495, 0.028722782230880397, 0.02862095807657207, 0.02851913392226375, 0.028417309846254575, 0.028315488258226464, 0.028213664103918144, 0.028111839949609824, 0.028010018439880865, 0.027908194285572542, 0.027806370131264222, 0.027704546041457834, 0.027602724467226936, 0.027500900312918616, 0.0273990761906888, 0.027297254648881334, 0.027207481856866136, 0.0270682154933973, 0.026945710417353986, 0.02685939366630038, 0.02483712549153286, 0.0246603487269053, 0.024483571899155523, 0.02430679519902988, 0.024130018528568206, 0.02395324189501406, 0.023776465291296348, 0.023599688652568226, 0.023422911826715544, 0.02324613506139813, 0.023069358265381906, 0.02289258159629995, 0.022715804993617063, 0.022539028454056365, 0.022362251848614005, 0.022185475054839827, 0.022008698593923237, 0.02183192192673841, 0.021655145225405497, 0.021478368509930446, 0.02130159182618897, 0.021124815188323216, 0.02094803845715384, 0.020771261741161392, 0.02059448502447909, 0.020417708372471203, 0.020240931656651213, 0.020064154957042953, 0.026805878862400167, 0.02672879009491241, 0.02659080431381077, 0.026428115664694732, 0.026251338964913988, 0.026074562330325044, 0.025897785532584188, 0.02572100876743922, 0.025544232164583867, 0.025367455432034773, 0.025190678763470208, 0.02501390209663029, 0.016882174464986344, 0.016705397749511294, 0.01564473757945616, 0.015467960929345366, 0.015291184165235184, 0.01511440749615324, 0.014937630811376971, 0.014760854127980425, 0.014584077427682335, 0.014407300710655086, 0.014230524028983177, 0.014053747326994933, 0.01387697061074381, 0.013700193942679382, 0.013523417242467493, 0.013346640526388854, 0.013169863890316727, 0.012993087126016772, 0.012816310457814444, 0.012639533757775049, 0.012462757089710631, 0.012285980341380969, 0.012109203657208382, 0.01193242702120525, 0.011755650288949312, 0.011578873540602441, 0.011402096920707573, 0.011225320268596194, 0.011048543367721167, 0.010871766787907168, 0.010694990087833277, 0.010518213395554782, 0.010341436695498125, 0.010164660019241645, 0.009987883303145728, 0.00981110661083276, 0.009634329910793339, 0.009457553218463123, 0.009280776518423704, 0.009103999818229075, 0.008927223150250928, 0.008750446433999805, 0.01705895114907275, 0.01723572783557366, 0.01741250454932405, 0.017589281233927855, 0.017766057918359182, 0.017942834634006696, 0.018119611284979808, 0.018296388003041834, 0.018473164719724128, 0.018649941403120672, 0.018826718103246327, 0.019003494786987808, 0.01918027147090174, 0.019357048186894182, 0.01953382487236031, 0.019710601603874604, 0.019887378271404365, 0.01652862101765207, 0.01635184434960492, 0.016175067679488175, 0.015998290965737794, 0.015821514280444142, 0.005922019319550215, 0.0060987960116734435, 0.0062755727199221584, 0.006452349396006181, 0.006629126112257259, 0.006805902796395414, 0.006982679480533487, 0.007159456172656777, 0.0073362328728513735, 0. ...

# %%
color10_16 = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF',
              '#FECB52']
fig = make_subplots(
    rows=1,
    cols=2,
    shared_yaxes=True,
    x_title="Radius (m)",
    y_title="Velocity Magnitude (m/s)",
    subplot_titles=("Quadrant 1", "Quadrant 2"))


fig.add_trace(go.Scatter(x=quad_ascii["C4_SBES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C4_SBES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             size = 4.5,
                             symbol = 'triangle-right',),
                         line=dict(color='red')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C4_IDDES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C4_IDDES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             size = 4.5,
                             symbol = 'x'),
                         line=dict(color='green')),
              row=1, col=1)
fig.add_trace(go.Scatter(x=quad_ascii["C4_KW"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C4_KW"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         marker=dict(
                              color='blue',
                              size = 4.5,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                         name='KW-SST-ASCII',
                         line=dict(color='blue')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=C4_Experimental["Q1"]['radius'],
                         y=C4_Experimental["Q1"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                         line=dict(color='black')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C4_SBES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C4_SBES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             symbol = 'triangle-right'),
                         line=dict(color='red'),
                         showlegend=False),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C4_IDDES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C4_IDDES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             symbol = 'x'),
                         line=dict(color='green'),
                         showlegend=False),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C4_KW"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C4_KW"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-SST-ASCII',
                         line=dict(color='blue'),
                         showlegend=False),
              row=1, col=2)


fig.add_trace(go.Scatter(x=C4_Experimental["Q2"]['radius'],
                         y=C4_Experimental["Q2"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                         line=dict(color='black'),
                         showlegend=False),
              row=1, col=2)

fig.update_layout(height=400, width=1200,
                  title_text="Condition 4: Velocity Magnitude vs Experimental")

fig.show()
fig.write_image("/Users/jdtarriela/Downloads/C4-velomag.png")
# Out:
# <div>                            <div id="20b62d8a-952f-4db7-b561-dd7b8384f067" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20b62d8a-952f-4db7-b561-dd7b8384f067")) {                    Plotly.newPlot(                        "20b62d8a-952f-4db7-b561-dd7b8384f067",                        [{"line": {"color": "red"}, "marker": {"size": 4.5, "symbol": "triangle-right"}, "mode": "markers", "name": "SBES-ASCII", "type": "scatter", "x": [0.02685939366630038, 0.026945710417353986, 0.0270682154933973, 0.027207481856866136, 0.027297254648881334, 0.0273990761906888, 0.027500900312918616, 0.027602724467226936, 0.027704546041457834, 0.027806370131264222, 0.027908194285572542, 0.028010018439880865, 0.028111839949609824, 0.028213664103918144, 0.028315488258226464, 0.028417312348377785, 0.02851913392226375, 0.02862095807657207, 0.028722782230880397, 0.028824603754751495, 0.02892642789491768, 0.029028252049226006, 0.029130073573097097, 0.029231897727405424, 0.029333721881713737, 0.029435545957722926, 0.02953715153877151, 0.02960912519445417, 0.029726148487953623, 0.02981023941621481, 0.02984537145095264, 0.029876612800332616, 0.0299026595453081, 0.029924373083359927, 0.02994247251380029, 0.029957561083566373, 0.029970134021963427, 0.029980615409212416, 0.029992993419483107, 0.026805878926557173, 0.026728790223226426, 0.02659080431381077, 0.026428115664694732, 0.026251338964913988, 0.026074562330325044, 0.025897785532584188, 0.02572100876743922, 0.025544232164583867, 0.025367455432034773, 0.025190678763470208, 0.02501390209663029, 0.02483712549153286, 0.0246603487269053, 0.024483571899155523, 0.02430679519902988, 0.024130018528568206, 0.02395324189501406, 0.023776465291296348, 0.023599688652568226, 0.023422911826715544, 0.02324613506139813, 0.023069358265381906, 0.02289258159629995, 0.022715804993617063, 0.022539028454056365, 0.022362251848614005, 0.022185475054839827, 0.022008698593923237, 0.02183192192673841, 0.021655145225405497, 0.021478368509930446, 0.02130159182618897, 0.021124815188323216, 0.02094803845715384, 0.020771261741161392, 0.02059448502447909, 0.020417708372471203, 0.020240931656651213, 0.020064154957042953, 0.019887378271404365, 0.019710601603874604, 0.01953382487236031, 0.019357048186894182, 0.01918027147090174, 0.019003494786987808, 0.018826718103246327, 0.018649941403120672, 0.004006315132562008, 0.004018580885474775, 0.004035238222926027, 0.004056513976941254, 0.004074573523937696, 0.0040962914342722034, 0.004122420444274813, 0.004153872578805947, 0.004206311839665735, 0.004329752003591482, 0.004507801913979152, 0.004684582273714052, 0.004861358977875338, 0.005038135682140099, 0.005214912374159849, 0.005391689070353259, 0.00556846581475064, 0.005745242635343107, 0.012639533757775049, 0.01193242702120525, 0.011755650288949312, 0.011578873540602441, 0.011402096920707573, 0.011225320268596194, 0.011048543367721167, 0.010871766787907168, 0.010694990087833277, 0.010518213395554782, 0.010341436695498125, 0.010164660019241645, 0.009987883303145728, 0.00981110661083276, 0.009634329910793339, 0.009457553218463123, 0.009280776518423704, 0.009103999818229075, 0.008927223150250928, 0.00804333965740091, 0.007866562965329386, 0.007689786257166873, 0.00751300958103113, 0.0073362328728513735, 0.007159456172656777, 0.006982679480533487, 0.006805902796395414, 0.006629126112257259, 0.006452349396006181, 0.0062755727199221584, 0.0060987960116734435, 0.005922019319550215, 0.008220116349506914, 0.008396893057790159, 0.008573669741859294, 0.008750446433999805, 0.012462757089710631, 0.012285980341380969, 0.012109203657208382, 0.012816310457814444, 0.012993087126016772, 0.013169863890316727, 0.013346640526388854, 0.013523417242467493, 0.013700193942679382, 0.01387697061074381, 0.014053747326994933, 0.01423052 ...

# %%
color10_16 = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF',
              '#FECB52']
fig = make_subplots(
    rows=1,
    cols=2,
    shared_yaxes=True,
    x_title="Radius (m)",
    y_title="Velocity Magnitude (m/s)",
    subplot_titles=("Quadrant 1", "Quadrant 2"))


fig.add_trace(go.Scatter(x=quad_ascii["C5_SBES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C5_SBES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             symbol = 'triangle-right'),
                         line=dict(color='red')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C5_IDDES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C5_IDDES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             symbol = 'x'),
                         line=dict(color='green')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C5_KW"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C5_KW"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-ASCII',
                         line=dict(color='blue')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=C5_Experimental["Q1"]['radius'],
                         y=C5_Experimental["Q1"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                         line=dict(color='black')),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C5_SBES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C5_SBES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             symbol = 'triangle-right'),
                         line=dict(color='red'),
                         showlegend=False),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C5_IDDES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C5_IDDES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             symbol = 'x'),
                         line=dict(color='green'),
                         showlegend=False),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C5_KW"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C5_KW"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         opacity=0.5,
                         name='KW-SST-ASCII',
                         line=dict(color='blue'),
              showlegend=False),
              row=1, col=2)


fig.add_trace(go.Scatter(x=C5_Experimental["Q2"]['radius'],
                         y=C5_Experimental["Q2"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         opacity=0.5,
                         name='Experimental',
                         line=dict(color='black'),
                         showlegend=False),
              row=1, col=2)

fig.update_layout(height=400, width=1200,
                  title_text="Condition 5: Velocity Magnitude vs Experimental")



fig.write_image("/Users/jdtarriela/Downloads/C5-velomag.png")
fig.show()
# Out:
# <div>                            <div id="5a5b3c7c-8ebb-430f-984b-d6f07f1e9fb6" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a5b3c7c-8ebb-430f-984b-d6f07f1e9fb6")) {                    Plotly.newPlot(                        "5a5b3c7c-8ebb-430f-984b-d6f07f1e9fb6",                        [{"line": {"color": "red"}, "marker": {"symbol": "triangle-right"}, "mode": "markers", "name": "SBES-ASCII", "type": "scatter", "x": [0.02094803845715384, 0.021124815188323216, 0.02130159182618897, 0.021478368509930446, 0.021655145225405497, 0.02183192192673841, 0.022008698593923237, 0.022185475054839827, 0.022362251848614005, 0.022539028454056365, 0.022715804993617063, 0.02289258159629995, 0.023069358265381906, 0.015291184165235184, 0.015467960929345366, 0.01564473757945616, 0.015821514280444142, 0.015998290965737794, 0.016175067679488175, 0.01635184434960492, 0.01652862101765207, 0.016705397749511294, 0.016882174464986344, 0.01705895114907275, 0.01723572783557366, 0.01741250454932405, 0.017589281233927855, 0.017766057918359182, 0.017942834634006696, 0.018119611284979808, 0.018296388003041834, 0.018473164719724128, 0.018649941403120672, 0.018826718103246327, 0.019003494786987808, 0.01918027147090174, 0.019357048186894182, 0.01953382487236031, 0.019710601603874604, 0.019887378271404365, 0.020064154957042953, 0.020240931656651213, 0.020417708372471203, 0.02059448502447909, 0.020771261741161392, 0.02501390209663029, 0.025190678763470208, 0.025367455432034773, 0.025544232164583867, 0.02572100876743922, 0.025897785532584188, 0.026074562330325044, 0.026251338964913988, 0.026428115664694732, 0.026590804445332634, 0.0267287899665984, 0.026805878798243157, 0.02685939366630038, 0.026945710417353986, 0.0270682154933973, 0.027207481856866136, 0.027297254648881334, 0.027399076511473833, 0.027500900312918616, 0.027602724467226936, 0.027704548621535263, 0.027806370131264222, 0.027908194285572542, 0.028010018439880865, 0.028111840014111763, 0.028213664103918144, 0.028315488258226464, 0.028417311386022708, 0.009987883303145728, 0.00981110661083276, 0.009634329910793339, 0.009457553218463123, 0.009280776518423704, 0.009103999818229075, 0.008927223150250928, 0.008750446433999805, 0.008573669741859294, 0.008396893057790159, 0.008220116349506914, 0.00804333965740091, 0.007866562965329386, 0.007689786257166873, 0.00751300958103113, 0.0073362328728513735, 0.007159456172656777, 0.006982679480533487, 0.006805902796395414, 0.006629126112257259, 0.006452349396006181, 0.0062755727199221584, 0.0060987960116734435, 0.005922019319550215, 0.005745242635343107, 0.00556846581475064, 0.005391689070353259, 0.005214912374159849, 0.005038135682140099, 0.004861358977875338, 0.004684582273714052, 0.004507801913979152, 0.004329752011403331, 0.004206311860924559, 0.004153872578805947, 0.004122420412127324, 0.004096291466419692, 0.004074573491790207, 0.004056513928720021, 0.004035238218890343, 0.004018580921640699, 0.004006315132596501, 0.01511440749615324, 0.014937630811376971, 0.014760854127980425, 0.014584077427682335, 0.014407300710655086, 0.014230524028983177, 0.014053747326994933, 0.01387697061074381, 0.013700193942679382, 0.013523417242467493, 0.013346640526388854, 0.013169863890316727, 0.012993087126016772, 0.012816310457814444, 0.012639533757775049, 0.012462757089710631, 0.012285980341380969, 0.012109203657208382, 0.01193242702120525, 0.011755650288949312, 0.011578873540602441, 0.011402096920707573, 0.011225320268596194, 0.011048543367721167, 0.010871766787907168, 0.010694990087833277, 0.010518213395554782, 0.010341436695498125, 0.010164660019241645, 0.02851913392226375, 0.02862095807657207, 0.028722782230880397, 0.028824603754751495, 0.02892642789491768, 0.029028252049226006, 0.02913007421466715, 0.029231897727405424, 0.0293337218817137 ...

# %%
df_length = len(quad_ascii["C1_SBES"]['Q1'])
df_length_list = np.arange(0, df_length, 1).tolist()
element_to_remove = df_length_list[::5]
quad_ascii["C1_SBES"]['Q1']=quad_ascii["C1_SBES"]['Q1'].drop(quad_ascii["C1_SBES"]['Q1'].index[element_to_remove])
quad_ascii["C4_SBES"]['Q1']=quad_ascii["C4_SBES"]['Q1'].drop(quad_ascii["C4_SBES"]['Q1'].index[element_to_remove])
quad_ascii["C5_SBES"]['Q1']=quad_ascii["C5_SBES"]['Q1'].drop(quad_ascii["C5_SBES"]['Q1'].index[element_to_remove])
quad_ascii["C1_SBES"]['Q2']=quad_ascii["C1_SBES"]['Q2'].drop(quad_ascii["C1_SBES"]['Q2'].index[element_to_remove])
quad_ascii["C4_SBES"]['Q2']=quad_ascii["C4_SBES"]['Q2'].drop(quad_ascii["C4_SBES"]['Q2'].index[element_to_remove])
quad_ascii["C5_SBES"]['Q2']=quad_ascii["C5_SBES"]['Q2'].drop(quad_ascii["C5_SBES"]['Q2'].index[element_to_remove])



df_length = len(quad_ascii["C1_KW"]['Q1'])
df_length_list = np.arange(0, df_length, 1).tolist()
element_to_remove = df_length_list[::2]
quad_ascii["C1_KW"]['Q1']=quad_ascii["C1_KW"]['Q1'].drop(quad_ascii["C1_KW"]['Q1'].index[element_to_remove])
quad_ascii["C4_KW"]['Q1']=quad_ascii["C4_KW"]['Q1'].drop(quad_ascii["C4_KW"]['Q1'].index[element_to_remove])
quad_ascii["C5_KW"]['Q1']=quad_ascii["C5_KW"]['Q1'].drop(quad_ascii["C5_KW"]['Q1'].index[element_to_remove])
quad_ascii["C1_KW"]['Q2']=quad_ascii["C1_KW"]['Q2'].drop(quad_ascii["C1_KW"]['Q2'].index[element_to_remove])
quad_ascii["C4_KW"]['Q2']=quad_ascii["C4_KW"]['Q2'].drop(quad_ascii["C4_KW"]['Q2'].index[element_to_remove])
quad_ascii["C5_KW"]['Q2']=quad_ascii["C5_KW"]['Q2'].drop(quad_ascii["C5_KW"]['Q2'].index[element_to_remove])



df_length = len(quad_ascii["C1_IDDES"]['Q1'])
df_length_list = np.arange(0, df_length, 1).tolist()
element_to_remove = df_length_list[::3]
quad_ascii["C1_IDDES"]['Q1']=quad_ascii["C1_IDDES"]['Q1'].drop(quad_ascii["C1_IDDES"]['Q1'].index[element_to_remove])
quad_ascii["C4_IDDES"]['Q1']=quad_ascii["C4_IDDES"]['Q1'].drop(quad_ascii["C4_IDDES"]['Q1'].index[element_to_remove])
quad_ascii["C5_IDDES"]['Q1']=quad_ascii["C5_IDDES"]['Q1'].drop(quad_ascii["C5_IDDES"]['Q1'].index[element_to_remove])
quad_ascii["C1_IDDES"]['Q2']=quad_ascii["C1_IDDES"]['Q2'].drop(quad_ascii["C1_IDDES"]['Q2'].index[element_to_remove])
quad_ascii["C4_IDDES"]['Q2']=quad_ascii["C4_IDDES"]['Q2'].drop(quad_ascii["C4_IDDES"]['Q2'].index[element_to_remove])
quad_ascii["C5_IDDES"]['Q2']=quad_ascii["C5_IDDES"]['Q2'].drop(quad_ascii["C5_IDDES"]['Q2'].index[element_to_remove])

# %%
fig = make_subplots(
    rows=3,
    cols=2,
    shared_yaxes=True,
    x_title="Radius (m)",
    y_title="Velocity Magnitude (m/s)",
    subplot_titles=("C1 Quadrant 1", "C1 Quadrant 2", "C4 Quadrant 1", "C4 Quadrant 2", "C5 Quadrant 1", "C5 Quadrant 2"),
    vertical_spacing=.07, horizontal_spacing=.02)



fig.add_trace(go.Scatter(x=quad_ascii["C1_SBES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C1_SBES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size=7,
                              line=dict(color='red'),
                              symbol = 'triangle-right')
                          ),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C1_IDDES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C1_IDDES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size=7,
                              line=dict(color='green'),
                              symbol = 'x')
                          ),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C1_KW"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C1_KW"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size=7,
                              line=dict(color='blue'),
                              symbol = 'circle')
                          ),
              row=1, col=1)


fig.add_trace(go.Scatter(x=C1_Experimental["Q1"]['radius'],
                         y=C1_Experimental["Q1"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                          marker=dict(
                              color='black',
                              size=7,
                              line=dict(color='black'),
                              symbol = 'circle')
                          ),
              row=1, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C1_SBES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C1_SBES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                          marker=dict(
                              color='red',
                              size=7,
                              line=dict(color='red'),
                              symbol = 'triangle-right'),
                          showlegend=False
                          ),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C1_IDDES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C1_IDDES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                          marker=dict(
                              color='green',
                              size=7,
                              line=dict(color='green'),
                              symbol = 'x'),
                          showlegend=False
                          ),
              row=1, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C1_KW"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C1_KW"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-SST-ASCII',
                          marker=dict(
                              color='blue',
                              size=7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                          showlegend=False
                          ),
              row=1, col=2)



fig.add_trace(go.Scatter(x=C1_Experimental["Q2"]['radius'],
                         y=C1_Experimental["Q2"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                          marker=dict(
                              color='black',
                              size=7,
                              line=dict(color='black'),
                              symbol = 'circle'),
                          showlegend=False),

              row=1, col=2)


fig.add_trace(go.Scatter(x=quad_ascii["C4_SBES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C4_SBES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'triangle-right',),
                         line=dict(color='red'),
                         showlegend=False),
              row=2, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C4_IDDES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C4_IDDES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'x'),
                         line=dict(color='green'),
                         showlegend=False),
              row=2, col=1)
fig.add_trace(go.Scatter(x=quad_ascii["C4_KW"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C4_KW"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         marker=dict(
                              color='blue',
                              size=7,
                              line=dict(color='blue'),
                              symbol = 'circle'),
                         name='KW-SST-ASCII',
                         line=dict(color='blue'),
                         showlegend=False),
              row=2, col=1)

fig.add_trace(go.Scatter(x=C4_Experimental["Q1"]['radius'],
                         y=C4_Experimental["Q1"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         marker=dict(
                           size=7
                         ),
                         name='Experimental',
                         line=dict(color='black'),
                         showlegend=False),
              row=2, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C4_SBES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C4_SBES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'triangle-right'),
                         line=dict(color='red'),
                         showlegend=False),
              row=2, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C4_IDDES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C4_IDDES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'x'),
                         line=dict(color='green'),
                         showlegend=False),
              row=2, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C4_KW"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C4_KW"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-SST-ASCII',
                         marker=dict(
                             size=7
                         ),
                         line=dict(color='blue'),
                         showlegend=False),
              row=2, col=2)


fig.add_trace(go.Scatter(x=C4_Experimental["Q2"]['radius'],
                         y=C4_Experimental["Q2"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                         marker=dict(
                             size=7
                         ),
                         line=dict(color='black'),
                         showlegend=False),
              row=2, col=2)


fig.add_trace(go.Scatter(x=quad_ascii["C5_SBES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C5_SBES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'triangle-right'),
                         line=dict(color='red'),
                         showlegend=False),
              row=3, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C5_IDDES"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C5_IDDES"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'x'),
                         line=dict(color='green'),
                         showlegend=False),
              row=3, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C5_KW"]['Q1']['radius_bin_mean'],
                         y=quad_ascii["C5_KW"]['Q1']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='KW-ASCII',
                         marker=dict(
                             size=7
                         ),
                         line=dict(color='blue'),
                         showlegend=False),
              row=3, col=1)

fig.add_trace(go.Scatter(x=C5_Experimental["Q1"]['radius'],
                         y=C5_Experimental["Q1"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         name='Experimental',
                         marker=dict(
                             size=7
                         ),

                         line=dict(color='black'),
                         showlegend=False),

              row=3, col=1)

fig.add_trace(go.Scatter(x=quad_ascii["C5_SBES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C5_SBES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='SBES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'triangle-right'),
                         line=dict(color='red'),
                         showlegend=False),
              row=3, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C5_IDDES"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C5_IDDES"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         name='IDDES-ASCII',
                         marker=dict(
                             size=7,
                             symbol = 'x'),
                         line=dict(color='green'),
                         showlegend=False),
              row=3, col=2)

fig.add_trace(go.Scatter(x=quad_ascii["C5_KW"]['Q2']['radius_bin_mean'],
                         y=quad_ascii["C5_KW"]['Q2']['velocity-magnitude_bin_mean'],
                         mode='markers',
                         marker=dict(
                             size=7),
                         name='KW-SST-ASCII',
                         line=dict(color='blue'),
              showlegend=False),
              row=3, col=2)


fig.add_trace(go.Scatter(x=C5_Experimental["Q2"]['radius'],
                         y=C5_Experimental["Q2"]['Velocity_Magnitude'],
                         mode='markers+lines',
                         marker=dict(
                             size=7),
                         name='Experimental',
                         line=dict(color='black'),
                         showlegend=False),
              row=3, col=2)

fig.update_layout(height=1400, width=1600,
                  title_text="Velocity Magnitude vs Experimental",
                  font=dict(
                      family="Arial",
                      size=24),
                  )
fig.update_annotations(font_size=24)
fig.update_layout(legend= {'itemsizing': 'constant'})
fig.show()
fig.write_image("/Users/jdtarriela/Downloads/velomag.png")
# Out:
# <div>                            <div id="46342e62-6a45-4e29-ac3b-bc6b5abfcff0" class="plotly-graph-div" style="height:1400px; width:1600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46342e62-6a45-4e29-ac3b-bc6b5abfcff0")) {                    Plotly.newPlot(                        "46342e62-6a45-4e29-ac3b-bc6b5abfcff0",                        [{"marker": {"color": "red", "line": {"color": "red"}, "size": 7, "symbol": "triangle-right"}, "mode": "markers", "name": "SBES-ASCII", "type": "scatter", "x": [0.029980615409212416, 0.029970134021963427, 0.029957561083566373, 0.029942472577957305, 0.0299026595453081, 0.029876612800332616, 0.02984537145095264, 0.02981023941621481, 0.02960912519445417, 0.02953715153877151, 0.02943554602187993, 0.029333721881713737, 0.029130073637254103, 0.029028252049226006, 0.02892642789491768, 0.028824603754751495, 0.02862095807657207, 0.02851913392226375, 0.028417309846254575, 0.028315488258226464, 0.028111839949609824, 0.028010018439880865, 0.027908194285572542, 0.027806370131264222, 0.027602724467226936, 0.027500900312918616, 0.0273990761906888, 0.027297254648881334, 0.0270682154933973, 0.026945710417353986, 0.02685939366630038, 0.02483712549153286, 0.024483571899155523, 0.02430679519902988, 0.024130018528568206, 0.02395324189501406, 0.023599688652568226, 0.023422911826715544, 0.02324613506139813, 0.023069358265381906, 0.022715804993617063, 0.022539028454056365, 0.022362251848614005, 0.022185475054839827, 0.02183192192673841, 0.021655145225405497, 0.021478368509930446, 0.02130159182618897, 0.02094803845715384, 0.020771261741161392, 0.02059448502447909, 0.020417708372471203, 0.020064154957042953, 0.026805878862400167, 0.02672879009491241, 0.02659080431381077, 0.026251338964913988, 0.026074562330325044, 0.025897785532584188, 0.02572100876743922, 0.025367455432034773, 0.025190678763470208, 0.02501390209663029, 0.016882174464986344, 0.01564473757945616, 0.015467960929345366, 0.015291184165235184, 0.01511440749615324, 0.014760854127980425, 0.014584077427682335, 0.014407300710655086, 0.014230524028983177, 0.01387697061074381, 0.013700193942679382, 0.013523417242467493, 0.013346640526388854, 0.012993087126016772, 0.012816310457814444, 0.012639533757775049, 0.012462757089710631, 0.012109203657208382, 0.01193242702120525, 0.011755650288949312, 0.011578873540602441, 0.011225320268596194, 0.011048543367721167, 0.010871766787907168, 0.010694990087833277, 0.010341436695498125, 0.010164660019241645, 0.009987883303145728, 0.00981110661083276, 0.009457553218463123, 0.009280776518423704, 0.009103999818229075, 0.008927223150250928, 0.01705895114907275, 0.01723572783557366, 0.01741250454932405, 0.017589281233927855, 0.017942834634006696, 0.018119611284979808, 0.018296388003041834, 0.018473164719724128, 0.018826718103246327, 0.019003494786987808, 0.01918027147090174, 0.019357048186894182, 0.019710601603874604, 0.019887378271404365, 0.01652862101765207, 0.01635184434960492, 0.015998290965737794, 0.015821514280444142, 0.005922019319550215, 0.0060987960116734435, 0.006452349396006181, 0.006629126112257259, 0.006805902796395414, 0.006982679480533487, 0.0073362328728513735, 0.00751300958103113, 0.007689786257166873, 0.007866562965329386, 0.008220116349506914, 0.008396893057790159, 0.008573669741859294, 0.004006315132562008, 0.0040352382329721164, 0.004056513976941254, 0.004074573523937696, 0.0040962914463275124, 0.004153872578805947, 0.004206311818406912, 0.004329752003591482, 0.004507801913979152, 0.004861358977875338, 0.005038135682140099, 0.005214912374159849, 0.005391689070353259, 0.005745242635343107, 0.02659632068968135, 0.004515195437021271, 0.00438376319033238, 0.004197247054001896, 0.004326620294697583, 0.0044175871555896026], "xaxis": "x", "y": [0.7830530778390243, 1.1914397144292683, 1.6649317410731705, 2.1955277996829268, 3.30147 ...

# %%
trace1 = go.Scatter(
    x=[0, 1, 2],
    y=[10, 11, 12]
)

trace2 = go.Scatter(
    x=[2, 3, 4],
    y=[100, 110, 120],
)
trace3 = go.Scatter(
    x=[3, 4, 5],
    y=[1000, 1100, 1200],
)
trace4= go.Scatter(x=C5_Experimental["Q2"]['radius'],
                   y=C5_Experimental["Q2"]['Velocity_Magnitude'])

fig = make_subplots(rows=3, cols=1,
                          vertical_spacing=0.1,
                          subplot_titles=('subtitle 1', 'subtitle 2', 'subtitle 3'),
                          row_width=[0.2, 0.4, 0.2]
                         )

fig.append_trace(trace1, 3, 1)
fig.append_trace(trace2, 2, 1)
fig.append_trace(trace4, 1, 1)

fig['layout'].update(height=600, width=600, title='Subplots with Shared X-Axes')
go.FigureWidget(fig)
# Out:
# FigureWidget({
#     'data': [{'type': 'scatter',
#               'uid': 'a1d40336-eb6d-46f8-9d90-a29abe6966e2',
#  …
